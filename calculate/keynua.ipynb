# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
g_x = [
	100.57777777777787,
	429.45555555555495,
	250.56666666666683,
	237.21111111111142,
]
e_x = [
	114,
	464,
	274,
	260,
]

g_y = [
	97.22222222222229,
	65.54444444444448,
	52.81111111111102,
	544.4666666666658,
]
e_y = [
	101,
	67,
	54.5,
	578.5,
]

g_h = [
	23,
	55,
	130,
	211,
]
e_h = [
	26,
	60,
	140,
	225,
]

g_w = [
	117,
	64,
	80,
	80,
]
e_w = [
	123,
	66,
	82.5,
	83,
]

res_x = np.polyfit(g_x, e_x, 1)
res_y = np.polyfit(g_y, e_y, 1)

res_h = np.polyfit(g_h, e_h, 1)
res_w = np.polyfit(g_w, e_w, 1)

fig, axes = plt.subplots(2, 2)
((ax1, ax2), (ax3, ax4)) = axes

ax1.plot(g_x, e_x, "o")
_x = np.linspace(50, 400)
ax1.plot(_x, res_x[0] * _x + res_x[1])

ax2.plot(g_y, e_y, "o")
_y = np.linspace(50, 700)
ax2.plot(_y, res_y[0] * _y + res_y[1])

ax3.plot(g_h, e_h, "o")
_h = np.linspace(0, 300)
ax3.plot(_h, res_h[0] * _h + res_h[1])

ax4.plot(g_w, e_w, "o")
_w = np.linspace(50, 150)
ax4.plot(_w, res_w[0] * _w + res_w[1])

plt.show()

# %%
res_x
# Out:
# array([1.06401155, 7.25930473])

# %%
res_y
# Out:
# array([ 1.06703604, -2.4987044 ])

# %%
res_w
# Out:
# array([ 1.07864334, -3.32934478])

# %%
res_h
# Out:
# array([1.05909484, 1.80981515])

# %%
g_x = [
	91.42640366210941,
	465.1864036621094,
	257.5192036621094,
]
e_x = [
	114,
	464,
	274,
]

g_y = [
	106.79296,
	71.77216000000003,
	684.32896,
]
e_y = [
	101,
	67,
	54.5,
]

res_x = np.polyfit(g_x, e_x, 1)
res_y = np.polyfit(g_y, e_y, 1)

fig, axes = plt.subplots(1, 2)
(ax1, ax2) = axes

ax1.plot(g_x, e_x, "o")
_x = np.linspace(50, 400)
ax1.plot(_x, res_x[0] * _x + res_x[1])

ax2.plot(g_y, e_y, "o")
_y = np.linspace(50, 700)
ax2.plot(_y, res_y[0] * _y + res_y[1])

plt.show()

# %% [markdown]
# # PSPDFKit convert

# %%
[91.42640366210941, 106.79296, 143.6224, 19.2]
[465.1864036621094, 71.77216000000003, 56.787199999999956, 56.8832]
[257.31440366210944, 664.8729600000001, 91.19360000000003, 58.31679999999993]

g_x = [
	91.42640366210941,
	465.1864036621094,
	257.31440366210944,
]
e_x = [
	85.94081944238283,
	436,
	241.5,
]

g_y = [
	106.79296,
	71.77216000000003,
	664.8729600000001,
]
e_y = [
	100.38538239999998,
	67.46583040000002,
	624,
]

g_w = [
	143.6224,
	56.787199999999956,
	91.19360000000003,
]
e_w = [
	134.5,
	52,
	85,
]

g_h = [
	19.2,
	56.8832,
	58.31679999999993,
]
e_h = [
	18,
	53.5,
	54,
]


res_x = np.polyfit(g_x, e_x, 1)
res_y = np.polyfit(g_y, e_y, 1)

res_h = np.polyfit(g_h, e_h, 1)
res_w = np.polyfit(g_w, e_w, 1)

fig, axes = plt.subplots(2, 2)
((ax1, ax2), (ax3, ax4)) = axes

ax1.plot(g_x, e_x, "o")
_x = np.linspace(50, 500)
ax1.plot(_x, res_x[0] * _x + res_x[1])

ax2.plot(g_y, e_y, "o")
_y = np.linspace(50, 700)
ax2.plot(_y, res_y[0] * _y + res_y[1])

ax3.plot(g_w, e_w, "o")
_w = np.linspace(50, 150)
ax3.plot(_w, res_w[0] * _w + res_w[1])

ax4.plot(g_h, e_h, "o")
_h = np.linspace(0, 100)
ax4.plot(_h, res_h[0] * _h + res_h[1])

plt.show()

# %%
print(f"""Res x: {res_x}
Res y: {res_y}
Res w: {res_w}
Res h: {res_h}
""")
# Out:
# Res x: [0.93655013 0.38572674]
# Res y: [0.93830111 0.15077667]
# Res w: [ 0.9495865  -1.80082101]
# Res h: [0.93038161 0.15223731]

# %% [markdown]
# # Final backend adjust

# %%
g = {
    "x": [
        86.42631578947369,
        420,
        187.5,
        286.1631578947368,
        187.1736842105263,
    ],
    "y": [
        99,
        93,
        341.5,
        341.5,
        622.4421052631574,
    ],
    "w": [
        134,
        61,
        94,
        105,
        140,
    ],
    "h": [
        20,
        44,
        50,
        50,
        32,
    ],
}

e = {
    "x": [
        91,
        447,
        200,
        305,
        200,
    ],
    "y": [
        106,
        100,
        364.5,
        364,
        664,
    ],
    "w": [
        143,
        64,
        99,
        111,
        147,
    ],
    "h": [
        20.5,
        46,
        52,
        52,
        33,
    ],
}

res_x = np.polyfit(g["x"], e["x"], 1)
res_y = np.polyfit(g["y"], e["y"], 1)

res_h = np.polyfit(g["h"], e["h"], 1)
res_w = np.polyfit(g["w"], e["w"], 1)

fig, axes = plt.subplots(2, 2)
((ax1, ax2), (ax3, ax4)) = axes

ax1.plot(g["x"], e["x"], "o")
_x = np.linspace(50, 500)
ax1.plot(_x, res_x[0] * _x + res_x[1])

ax2.plot(g["y"], e["y"], "o")
_y = np.linspace(50, 700)
ax2.plot(_y, res_y[0] * _y + res_y[1])

ax3.plot(g["w"], e["w"], "o")
_w = np.linspace(50, 150)
ax3.plot(_w, res_w[0] * _w + res_w[1])

ax4.plot(g["h"], e["h"], "o")
_h = np.linspace(15, 60)
ax4.plot(_h, res_h[0] * _h + res_h[1])

plt.show()

# %%
print(f"""Res x: {res_x}
Res y: {res_y}
Res w: {res_w}
Res h: {res_h}
""")
# Out:
# Res x: [ 1.06602574 -0.26651497]
# Res y: [1.0654769 0.6020044]
# Res w: [ 1.06452713 -0.89149703]
# Res h: [ 1.05319149 -0.58510638]
